# %% [markdown]
# # **📁Dataset Preperation📁**
# Downloading and importing datasets, files and functions.

# %%
#@title Imports/Download

# !pip install tf2onnx
# !pip install coremltools


import numpy as np

import random


import tensorflow as tf
import pandas as pd
import requests
import json
import glob
import os
import PIL
import tempfile
from PIL import Image
from google.colab import drive
from tensorflow.python.framework import graph_util
from tensorflow.python.framework import ops
from tensorflow.keras import Sequential
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
from tensorflow.python.keras import backend as K
from tensorflow.python.keras.models import load_model
import tf2onnx
import onnx



#Download dataset files
# !git clone https://github.com/L0ADIN9/PAG_Dataset.git
# !unzip /content/PAG_Dataset/Single_Sprite_Sheet.zip
#Plotting Import
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
plt.style.use('bmh')
# Out:
# Collecting tf2onnx
#   Downloading tf2onnx-1.16.1-py3-none-any.whl (455 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 455.8/455.8 kB 6.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.14.1 in /usr/local/lib/python3.10/dist-packages (from tf2onnx) (1.25.2)
# Collecting onnx>=1.4.1 (from tf2onnx)
#   Downloading onnx-1.16.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (15.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.9/15.9 MB 45.7 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from tf2onnx) (2.31.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from tf2onnx) (1.16.0)
# Requirement already satisfied: flatbuffers>=1.12 in /usr/local/lib/python3.10/dist-packages (from tf2onnx) (24.3.25)
# Requirement already satisfied: protobuf~=3.20 in /usr/local/lib/python3.10/dist-packages (from tf2onnx) (3.20.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->tf2onnx) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->tf2onnx) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->tf2onnx) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->tf2onnx) (2024.6.2)
# Installing collected packages: onnx, tf2onnx
# Successfully installed onnx-1.16.1 tf2onnx-1.16.1
# Collecting coremltools
#   Downloading coremltools-7.2-cp310-none-manylinux1_x86_64.whl (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 5.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.10/dist-packages (from coremltools) (1.25.2)
# Requirement already satisfied: protobuf<=4.0.0,>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from coremltools) (3.20.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from coremltools) (1.12.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from coremltools) (4.66.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from coremltools) (24.1)
# Requirement already satisfied: attrs>=21.3.0 in /usr/local/lib/python3.10/dist-packages (from coremltools) (23.2.0)
# Collecting cattrs (from coremltools)
#   Downloading cattrs-23.2.3-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 7.5 MB/s eta 0:00:00
# Collecting pyaml (from coremltools)
#   Downloading pyaml-24.4.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: exceptiongroup>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from cattrs->coremltools) (1.2.1)
# Requirement already satisfied: typing-extensions!=4.6.3,>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from cattrs->coremltools) (4.12.2)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from pyaml->coremltools) (6.0.1)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->coremltools) (1.3.0)
# Installing collected packages: pyaml, cattrs, coremltools
# Successfully installed cattrs-23.2.3 coremltools-7.2 pyaml-24.4.0
# Cloning into 'PAG_Dataset'...
# remote: Enumerating objects: 50, done.
# remote: Counting objects: 100% (1/1), done.
# remote: Total 50 (delta 0), reused 0 (delta 0), pack-reused 49
# Receiving objects: 100% (50/50), 2.81 MiB | 26.66 MiB/s, done.
# Resolving deltas: 100% (8/8), done.
# Archive:  /content/PAG_Dataset/Single_Sprite_Sheet.zip
#    creating: Single_Sprite_Sheet/
#   inflating: __MACOSX/._Single_Sprite_Sheet
#   inflating: Single_Sprite_Sheet/4Attack_1.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._4Attack_1.png
#   inflating: Single_Sprite_Sheet/Walk copy 2.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Walk copy 2.png
#   inflating: Single_Sprite_Sheet/Punk_run.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Punk_run.png
#   inflating: Single_Sprite_Sheet/Biker_punch.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Biker_punch.png
#   inflating: Single_Sprite_Sheet/Bite.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Bite.png
#   inflating: Single_Sprite_Sheet/ZOMBIEScream.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._ZOMBIEScream.png
#   inflating: Single_Sprite_Sheet/Pink_Monster_Hurt_4.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Pink_Monster_Hurt_4.png
#   inflating: Single_Sprite_Sheet/De25d.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._De25d.png
#   inflating: Single_Sprite_Sheet/Idle2 copy.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Idle2 copy.png
#   inflating: Single_Sprite_Sheet/Player Running Aiming 48x48.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Player Running Aiming 48x48.png
#   inflating: Single_Sprite_Sheet/Punk_climb.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Punk_climb.png
#   inflating: Single_Sprite_Sheet/4Jump.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._4Jump.png
#   inflating: Single_Sprite_Sheet/Walk copy 3.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Walk copy 3.png
#   inflating: Single_Sprite_Sheet/4Attack_2.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._4Attack_2.png
#   inflating: Single_Sprite_Sheet/player katana run 48x48.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._player katana run 48x48.png
#   inflating: Single_Sprite_Sheet/Death copy 4.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Death copy 4.png
#   inflating: Single_Sprite_Sheet/Swim2 copy.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Swim2 copy.png
#   inflating: Single_Sprite_Sheet/Pink_Monster_Run_6.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Pink_Monster_Run_6.png
#   inflating: Single_Sprite_Sheet/Double_Jump_Dust_5 copy 2.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Double_Jump_Dust_5 copy 2.png
#   inflating: Single_Sprite_Sheet/Death copy 5.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Death copy 5.png
#   inflating: Single_Sprite_Sheet/Idleretr.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Idleretr.png
#   inflating: Single_Sprite_Sheet/Idledfghkj.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Idledfghkj.png
#   inflating: Single_Sprite_Sheet/Jump.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Jump.png
#   inflating: Single_Sprite_Sheet/W25lk.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._W25lk.png
#   inflating: Single_Sprite_Sheet/4Attack_3.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._4Attack_3.png
#   inflating: Single_Sprite_Sheet/Walk copy 4.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Walk copy 4.png
#   inflating: Single_Sprite_Sheet/Biker_attack1.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Biker_attack1.png
#   inflating: Single_Sprite_Sheet/PlayerWalk 48x48.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._PlayerWalk 48x48.png
#   inflating: Single_Sprite_Sheet/Cyborg_punch.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Cyborg_punch.png
#   inflating: Single_Sprite_Sheet/run cycle 48x48.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._run cycle 48x48.png
#   inflating: Single_Sprite_Sheet/Owlet_Monster_Walk+Attack_6.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Owlet_Monster_Walk+Attack_6.png
#   inflating: Single_Sprite_Sheet/ZOMBIERun.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._ZOMBIERun.png
#   inflating: Single_Sprite_Sheet/Biker_death.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Biker_death.png
#   inflating: Single_Sprite_Sheet/.DS_Store
#   inflating: __MACOSX/Single_Sprite_Sheet/._.DS_Store
#   inflating: Single_Sprite_Sheet/ZOMBIEIdle.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._ZOMBIEIdle.png
#   inflating: Single_Sprite_Sheet/Pink_Monster_Attack1_4.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Pink_Monster_Attack1_4.png
#   inflating: Single_Sprite_Sheet/Biker_run_attack.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Biker_run_attack.png
#   inflating: Single_Sprite_Sheet/Player Jab 48x48.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Player Jab 48x48.png
#   inflating: Single_Sprite_Sheet/Dude_Monster_Hurt_4.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Dude_Monster_Hurt_4.png
#   inflating: Single_Sprite_Sheet/Owlet_Monster_Hurt_4.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Owlet_Monster_Hurt_4.png
#   inflating: Single_Sprite_Sheet/De2d.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._De2d.png
#   inflating: Single_Sprite_Sheet/Walk2.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Walk2.png
#   inflating: Single_Sprite_Sheet/Biker_attack2.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Biker_attack2.png
#   inflating: Single_Sprite_Sheet/Death copy 2.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Death copy 2.png
#   inflating: Single_Sprite_Sheet/8.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._8.png
#   inflating: Single_Sprite_Sheet/43436.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._43436.png
#   inflating: Single_Sprite_Sheet/ZOMBIEHurt.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._ZOMBIEHurt.png
#   inflating: Single_Sprite_Sheet/9.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._9.png
#   inflating: Single_Sprite_Sheet/Death copy 3.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Death copy 3.png
#   inflating: Single_Sprite_Sheet/Charge.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Charge.png
#   inflating: Single_Sprite_Sheet/Deathdfghkj.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Deathdfghkj.png
#   inflating: Single_Sprite_Sheet/Biker_attack3.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Biker_attack3.png
#   inflating: Single_Sprite_Sheet/Biker_climb.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Biker_climb.png
#   inflating: Single_Sprite_Sheet/aAttack.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._aAttack.png
#   inflating: Single_Sprite_Sheet/Pink_Monster_Idle_4.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Pink_Monster_Idle_4.png
#   inflating: Single_Sprite_Sheet/Swim copy 2.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Swim copy 2.png
#   inflating: Single_Sprite_Sheet/retrDeath.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._retrDeath.png
#   inflating: Single_Sprite_Sheet/Attack2 copy 2.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Attack2 copy 2.png
#   inflating: Single_Sprite_Sheet/Run+255tt255ck.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Run+255tt255ck.png
#   inflating: Single_Sprite_Sheet/4Hurt.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._4Hurt.png
#   inflating: Single_Sprite_Sheet/Punk_punch.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Punk_punch.png
#   inflating: Single_Sprite_Sheet/Attack2 copy 3.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Attack2 copy 3.png
#   inflating: Single_Sprite_Sheet/Idle.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Idle.png
#   inflating: Single_Sprite_Sheet/255tt255ck_2.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._255tt255ck_2.png
#   inflating: Single_Sprite_Sheet/Attack3 copy.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Attack3 copy.png
#   inflating: Single_Sprite_Sheet/Attack2 copy.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Attack2 copy.png
#   inflating: Single_Sprite_Sheet/Owlet_Monster_Walk_6.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Owlet_Monster_Walk_6.png
#   inflating: Single_Sprite_Sheet/Jump copy 5.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Jump copy 5.png
#   inflating: Single_Sprite_Sheet/Dude_Monster_Walk_6.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Dude_Monster_Walk_6.png
#   inflating: Single_Sprite_Sheet/4Idle.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._4Idle.png
#   inflating: Single_Sprite_Sheet/Pink_Monster_Walk+Attack_6.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Pink_Monster_Walk+Attack_6.png
#   inflating: Single_Sprite_Sheet/Jump copy 4.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Jump copy 4.png
#   inflating: Single_Sprite_Sheet/Hurt.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Hurt.png
#   inflating: Single_Sprite_Sheet/retrWalk.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._retrWalk.png
#   inflating: Single_Sprite_Sheet/Run copy 4.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Run copy 4.png
#   inflating: Single_Sprite_Sheet/player jump 48x48.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._player jump 48x48.png
#   inflating: Single_Sprite_Sheet/Cyborg_climb.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Cyborg_climb.png
#   inflating: Single_Sprite_Sheet/5Death.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._5Death.png
#   inflating: Single_Sprite_Sheet/W2lk.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._W2lk.png
#   inflating: Single_Sprite_Sheet/Player Roll 48x48.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Player Roll 48x48.png
#   inflating: Single_Sprite_Sheet/Double_Jump_Dust_5 copy.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Double_Jump_Dust_5 copy.png
#   inflating: Single_Sprite_Sheet/Owlet_Monster_Idle_4.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Owlet_Monster_Idle_4.png
#   inflating: Single_Sprite_Sheet/5Idle.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._5Idle.png
#   inflating: Single_Sprite_Sheet/aDeath.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._aDeath.png
#   inflating: Single_Sprite_Sheet/Dude_Monster_Idle_4.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Dude_Monster_Idle_4.png
#   inflating: Single_Sprite_Sheet/Punk_death.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Punk_death.png
#   inflating: Single_Sprite_Sheet/Idle2.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Idle2.png
#   inflating: Single_Sprite_Sheet/Punk_run_attack.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Punk_run_attack.png
#   inflating: Single_Sprite_Sheet/Owlet_Monster_Run_6.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Owlet_Monster_Run_6.png
#   inflating: Single_Sprite_Sheet/hWalk.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._hWalk.png
#   inflating: Single_Sprite_Sheet/Dude_Monster_Run_6.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Dude_Monster_Run_6.png
#   inflating: Single_Sprite_Sheet/Run copy 3.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Run copy 3.png
#   inflating: Single_Sprite_Sheet/ZOMBIEJump.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._ZOMBIEJump.png
#   inflating: Single_Sprite_Sheet/Jump copy 3.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Jump copy 3.png
#   inflating: Single_Sprite_Sheet/Eating.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Eating.png
#   inflating: Single_Sprite_Sheet/Hurtdfghkj.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Hurtdfghkj.png
#   inflating: Single_Sprite_Sheet/Pink_Monster_Walk_6.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Pink_Monster_Walk_6.png
#   inflating: Single_Sprite_Sheet/5Hurt.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._5Hurt.png
#   inflating: Single_Sprite_Sheet/aWalk.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._aWalk.png
#   inflating: Single_Sprite_Sheet/10.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._10.png
#   inflating: Single_Sprite_Sheet/Pink_Monster_Attack2_6.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Pink_Monster_Attack2_6.png
#   inflating: Single_Sprite_Sheet/Walkretr.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Walkretr.png
#   inflating: Single_Sprite_Sheet/Biker_run.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Biker_run.png
#   inflating: Single_Sprite_Sheet/Player Side-Climb 48x48.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Player Side-Climb 48x48.png
#   inflating: Single_Sprite_Sheet/Attack3.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Attack3.png
#   inflating: Single_Sprite_Sheet/5Attack3.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._5Attack3.png
#   inflating: Single_Sprite_Sheet/Run.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Run.png
#   inflating: Single_Sprite_Sheet/Owlet_Monster_Climb_4.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Owlet_Monster_Climb_4.png
#   inflating: Single_Sprite_Sheet/Dude_Monster_Push_6.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Dude_Monster_Push_6.png
#   inflating: Single_Sprite_Sheet/Owlet_Monster_Push_6.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Owlet_Monster_Push_6.png
#   inflating: Single_Sprite_Sheet/player crouch-walk 48x48.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._player crouch-walk 48x48.png
#   inflating: Single_Sprite_Sheet/1_2.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._1_2.png
#   inflating: Single_Sprite_Sheet/Punk_attack1.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Punk_attack1.png
#   inflating: Single_Sprite_Sheet/Attack copy.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Attack copy.png
#   inflating: Single_Sprite_Sheet/Owlet_Monster_Throw_4.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Owlet_Monster_Throw_4.png
#   inflating: Single_Sprite_Sheet/4Walk.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._4Walk.png
#   inflating: Single_Sprite_Sheet/2tt2ck_2.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._2tt2ck_2.png
#   inflating: Single_Sprite_Sheet/Attackretr.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Attackretr.png
#   inflating: Single_Sprite_Sheet/5Attack2.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._5Attack2.png
#   inflating: Single_Sprite_Sheet/retrIdle.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._retrIdle.png
#   inflating: Single_Sprite_Sheet/Attack2.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Attack2.png
#   inflating: Single_Sprite_Sheet/4Run.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._4Run.png
#   inflating: Single_Sprite_Sheet/Idle copy 2.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Idle copy 2.png
#   inflating: Single_Sprite_Sheet/Walk_Run_Push_Dust_6.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Walk_Run_Push_Dust_6.png
#   inflating: Single_Sprite_Sheet/Punk_attack3.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Punk_attack3.png
#   inflating: Single_Sprite_Sheet/Special.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Special.png
#   inflating: Single_Sprite_Sheet/5Special.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._5Special.png
#   inflating: Single_Sprite_Sheet/Punk_attack2.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Punk_attack2.png
#   inflating: Single_Sprite_Sheet/Run+Attack.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Run+Attack.png
#   inflating: Single_Sprite_Sheet/Walk copy.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Walk copy.png
#   inflating: Single_Sprite_Sheet/Owlet_Monster_Jump_8.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Owlet_Monster_Jump_8.png
#   inflating: Single_Sprite_Sheet/Idle copy 3.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Idle copy 3.png
#   inflating: Single_Sprite_Sheet/2tt2ck_1.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._2tt2ck_1.png
#   inflating: Single_Sprite_Sheet/5Attack1.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._5Attack1.png
#   inflating: Single_Sprite_Sheet/Dude_Monster_Jump_8.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Dude_Monster_Jump_8.png
#   inflating: Single_Sprite_Sheet/retrHurt.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._retrHurt.png
#   inflating: Single_Sprite_Sheet/Attack1.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Attack1.png
#   inflating: Single_Sprite_Sheet/Walk.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Walk.png
#   inflating: Single_Sprite_Sheet/player push idle 48x48.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._player push idle 48x48.png
#   inflating: Single_Sprite_Sheet/Dead.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Dead.png
#   inflating: Single_Sprite_Sheet/25tt25ck_2.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._25tt25ck_2.png
#   inflating: Single_Sprite_Sheet/Cyborg_run_attack.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Cyborg_run_attack.png
#   inflating: Single_Sprite_Sheet/Player Sword Idle 48x48.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Player Sword Idle 48x48.png
#   inflating: Single_Sprite_Sheet/Player Sword Run 48x48.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Player Sword Run 48x48.png
#   inflating: Single_Sprite_Sheet/Pink_Monster_Climb_4.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Pink_Monster_Climb_4.png
#   inflating: Single_Sprite_Sheet/Double_Jump_Dust_5.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Double_Jump_Dust_5.png
#   inflating: Single_Sprite_Sheet/Pink_Monster_Push_6.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Pink_Monster_Push_6.png
#   inflating: Single_Sprite_Sheet/hHurt.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._hHurt.png
#   inflating: Single_Sprite_Sheet/Pink_Monster_Throw_4.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Pink_Monster_Throw_4.png
#   inflating: Single_Sprite_Sheet/5Attack4.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._5Attack4.png
#   inflating: Single_Sprite_Sheet/Attack4.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Attack4.png
#   inflating: Single_Sprite_Sheet/aIdle.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._aIdle.png
#   inflating: Single_Sprite_Sheet/Player Pull 48x48.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Player Pull 48x48.png
#   inflating: Single_Sprite_Sheet/Idle2 copy 2.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Idle2 copy 2.png
#   inflating: Single_Sprite_Sheet/25tt25ck_1.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._25tt25ck_1.png
#   inflating: Single_Sprite_Sheet/Idle copy 4.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Idle copy 4.png
#   inflating: Single_Sprite_Sheet/4Dead.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._4Dead.png
#   inflating: Single_Sprite_Sheet/Pink_Monster_Jump_8.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Pink_Monster_Jump_8.png
#   inflating: Single_Sprite_Sheet/Owlet_Monster_Attack2_6.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Owlet_Monster_Attack2_6.png
#   inflating: Single_Sprite_Sheet/Dude_Monster_Climb_4.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Dude_Monster_Climb_4.png
#   inflating: Single_Sprite_Sheet/retrAttack.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._retrAttack.png
#   inflating: Single_Sprite_Sheet/Death copy.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Death copy.png
#   inflating: Single_Sprite_Sheet/Attack.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Attack.png
#   inflating: Single_Sprite_Sheet/Swim copy.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Swim copy.png
#   inflating: Single_Sprite_Sheet/player push 48x48.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._player push 48x48.png
#   inflating: Single_Sprite_Sheet/hIdle.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._hIdle.png
#   inflating: Single_Sprite_Sheet/Deathretr.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Deathretr.png
#   inflating: Single_Sprite_Sheet/Dude_Monster_Throw_4.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Dude_Monster_Throw_4.png
#   inflating: Single_Sprite_Sheet/Idle copy 5.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Idle copy 5.png
#   inflating: Single_Sprite_Sheet/5Walk.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._5Walk.png
#   inflating: Single_Sprite_Sheet/Dude_Monster_Attack1_4.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Dude_Monster_Attack1_4.png
#   inflating: Single_Sprite_Sheet/aHurt.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._aHurt.png
#   inflating: Single_Sprite_Sheet/W255lk.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._W255lk.png
#   inflating: Single_Sprite_Sheet/Attack copy 2.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Attack copy 2.png
#   inflating: Single_Sprite_Sheet/Dude_Monster_Walk+Attack_6.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Dude_Monster_Walk+Attack_6.png
#   inflating: Single_Sprite_Sheet/Attack_2.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Attack_2.png
#   inflating: Single_Sprite_Sheet/Attack_3.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Attack_3.png
#   inflating: Single_Sprite_Sheet/Walkdfghkj.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Walkdfghkj.png
#   inflating: Single_Sprite_Sheet/Walk_Run_Push_Dust_6 copy.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Walk_Run_Push_Dust_6 copy.png
#   inflating: Single_Sprite_Sheet/Walk_Run_Push_Dust_6 copy 2.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Walk_Run_Push_Dust_6 copy 2.png
#   inflating: Single_Sprite_Sheet/hDeath.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._hDeath.png
#   inflating: Single_Sprite_Sheet/ZOMBIEDead.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._ZOMBIEDead.png
#   inflating: Single_Sprite_Sheet/Cyborg_attack1.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Cyborg_attack1.png
#   inflating: Single_Sprite_Sheet/Attack copy 3.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Attack copy 3.png
#   inflating: Single_Sprite_Sheet/Cyborg_attack3.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Cyborg_attack3.png
#   inflating: Single_Sprite_Sheet/Attack_1.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Attack_1.png
#   inflating: Single_Sprite_Sheet/Owlet_Monster_Death_8.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Owlet_Monster_Death_8.png
#   inflating: Single_Sprite_Sheet/Swim.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Swim.png
#   inflating: Single_Sprite_Sheet/player air spin 48x48.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._player air spin 48x48.png
#   inflating: Single_Sprite_Sheet/Cyborg_attack2.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Cyborg_attack2.png
#   inflating: Single_Sprite_Sheet/Idle copy.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Idle copy.png
#   inflating: Single_Sprite_Sheet/Run+25tt25ck.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Run+25tt25ck.png
#   inflating: Single_Sprite_Sheet/Death.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Death.png
#   inflating: Single_Sprite_Sheet/Owlet_Monster_Attack1_4.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Owlet_Monster_Attack1_4.png
#   inflating: Single_Sprite_Sheet/Attack copy 4.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Attack copy 4.png
#   inflating: Single_Sprite_Sheet/Attack3 copy 2.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Attack3 copy 2.png
#   inflating: Single_Sprite_Sheet/Swim2 copy 2.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Swim2 copy 2.png
#   inflating: Single_Sprite_Sheet/Hurtretr.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Hurtretr.png
#   inflating: Single_Sprite_Sheet/Dude_Monster_Death_8.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Dude_Monster_Death_8.png
#   inflating: Single_Sprite_Sheet/Cyborg_run.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Cyborg_run.png
#   inflating: Single_Sprite_Sheet/Dude_Monster_Attack2_6.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Dude_Monster_Attack2_6.png
#   inflating: Single_Sprite_Sheet/player climb-back 48x48.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._player climb-back 48x48.png
#   inflating: Single_Sprite_Sheet/ZOMBIEAttack_1.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._ZOMBIEAttack_1.png
#   inflating: Single_Sprite_Sheet/ZOMBIEAttack_3.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._ZOMBIEAttack_3.png
#   inflating: Single_Sprite_Sheet/De255d.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._De255d.png
#   inflating: Single_Sprite_Sheet/hAttack.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._hAttack.png
#   inflating: Single_Sprite_Sheet/ZOMBIEWalk.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._ZOMBIEWalk.png
#   inflating: Single_Sprite_Sheet/1.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._1.png
#   inflating: Single_Sprite_Sheet/Pink_Monster_Death_8.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Pink_Monster_Death_8.png
#   inflating: Single_Sprite_Sheet/Swim2.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._Swim2.png
#   inflating: Single_Sprite_Sheet/player ledge climb 48x48.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._player ledge climb 48x48.png
#   inflating: Single_Sprite_Sheet/ZOMBIEAttack_2.png
#   inflating: __MACOSX/Single_Sprite_Sheet/._ZOMBIEAttack_2.png

# %%
#@title Formatting Functions
def ImageAugmentation (inp):
  i1 = []
  i2 = []
  i3 = []
  i4 = []
  i5 = []
  i6 = []
  i7 = []
  i8 = []
  i9 = []
  i10 = []
  for i in inp:
    i1.append(i)
    #i2.append(np.roll(i, -10,axis = 0))
    #i3.append(np.roll(i, 10,axis = 0))
    #i4.append(np.roll(i, -10,axis = 1))
    #i5.append(np.roll(i, 10,axis = 1))
    #i6.append(np.flip(i,1))
    #i7.append(np.flip(i,0))
    i8.append(np.rot90(i,1,))
    i9.append(np.rot90(i,2,))
    i10.append(np.rot90(i,3,))
  return i1,i2,i3,i4,i5,i6,i7,i8,i9,i10

def extractDataset(inp):
  finnalized_dataset_x1 = []
  finnalized_dataset_x2 = []
  finnalized_dataset_x3 = []
  for i in inp:
    wid = 1
    while (wid+2)<=len(i):
      for j in range(len(i)-wid-1):
        finnalized_dataset_x1.append( i[j])
        finnalized_dataset_x2.append(i[1+j+wid//2])
        finnalized_dataset_x3.append( i[1+j+wid])
      wid+=2
  return finnalized_dataset_x1, finnalized_dataset_x2, finnalized_dataset_x3

def imagePad(inp, leng):
  add = (leng-inp.shape[0])//2
  inp = np.pad(inp,((add,add),(add,add),(0,0)),'constant')
  return inp


def convToArray(inp, MLENG):
  base_animation = []
  for anim in inp:
    if anim.endswith("png"):
      ind = []
      img = np.array(mpimg.imread(anim))
      step = 0
      amnt = img.shape[1]//img.shape[0]
      w= img.shape[0]
      for i in range(amnt):
        new_img = img[:,step:w+step]
        step += w
        new_img = imagePad(new_img,MLENG)
        ind.append(new_img)
      i1,i2,i3,i4,i5,i6,i7,i8,i9,i10 = ImageAugmentation(ind)
      base_animation.append(i1)
      #base_animation.append(i2)
      #base_animation.append(i3)
     #base_animation.append(i4)
      #base_animation.append(i5)
      #base_animation.append(i6)
      #base_animation.append(i7)
      base_animation.append(i8)
      base_animation.append(i9)
      base_animation.append(i10)
  return base_animation

def displayDataset_x(inp):
  for i in inp:
    for k in i:
      imgplot = plt.imshow(np.array(k))
      plt.show()
def displayDataset_y(inp):
  for i in inp:
    imgplot = plt.imshow(np.array(i))
    plt.show()
def datasetShuffle(x):
  rng = np.random.default_rng()
  p = rng.permutation(len(x))
  return x[p]

# %%
Max_length = 96
dataset = convToArray(glob.glob("/content/Single_Sprite_Sheet/*.*"), Max_length)
random.shuffle(dataset)
print(len(dataset))

dataset_x1, dataset_x2, dataset_x3 = extractDataset(dataset)

dataset_x1 = np.array(dataset_x1)
dataset_x2 = np.array(dataset_x2)
dataset_x3 = np.array(dataset_x3)

text_x1 = dataset_x1[:10]
test_x2 = dataset_x2[:10]
test_x3 = dataset_x3[:10]

dataset_x1 = dataset_x1[10:]
dataset_x2 = dataset_x2[10:]
dataset_x3 = dataset_x3[10:]
print(np.shape(dataset_x1))

selec = 128
imgplot = plt.imshow(dataset_x1[selec])
plt.show()
imgplot = plt.imshow(dataset_x2[selec])
plt.show()
imgplot = plt.imshow(dataset_x3[selec])
plt.show()
print(dataset_x1.shape)
# Out:
# 844
# (5070, 96, 96, 4)
# (5070, 96, 96, 4)

# %%
for i in range(12,13):

  imgplot = plt.imshow(dataset_x1[i])
  plt.show()
  imgplot = plt.imshow(dataset_x2[i])
  plt.show()
  imgplot = plt.imshow(dataset_x3[i])
  plt.show()

# %% [markdown]
# # **🌴Generation of Model🌴**

# %%
#@title U-Net 2 Encoder/Decoder Functions
def Encoder(z_dim):
  inputs = layers.Input(shape = (Max_length, Max_length, 4))
  x = layers.Conv2D(filters=8, kernel_size= 5, strides=2, padding='same', activation='relu')(inputs)
  print(x.shape)
  x = layers.Conv2D(filters=12, kernel_size= 2, strides=2, padding='same', activation='relu')(x)
  print(x.shape)
  x = layers.Conv2D(filters=12, kernel_size= 2, strides=2, padding='same', activation='relu')(x)
  print(x.shape)
  x = layers.Conv2D(filters=16, kernel_size= 2, strides=1, padding='same', activation='relu')(x)
  print(x.shape)
  x = layers.Flatten()(x)
  print(x.shape)
  x = layers.Dense(z_dim, activation = 'relu')(x)
  print(x.shape)
  return tf.keras.Model(inputs = inputs, outputs = x, name = 'encoder')

def Decoder(z_dim):
  inputs = layers.Input(shape= z_dim * 2)
  x = layers.Dense(2*24*24*z_dim)(inputs)
  x = layers.Reshape((24,24,z_dim*2))(x)
  x = layers.Conv2D(filters=128, kernel_size=(2,2), strides=1, padding='same', activation='relu')(x)
  print(x.shape)
  x = layers.UpSampling2D((2,2))(x)
  print(x.shape)
  x = layers.Conv2D(filters=64, kernel_size=(3,3), strides=1, padding='same', activation='relu')(x)
  print(x.shape)
  x = layers.UpSampling2D((2,2))(x)
  print(x.shape)
  x = layers.Conv2D(filters=32, kernel_size=(3,3), strides=1, padding='same', activation='relu')(x)
  print(x.shape)
  x = layers.Conv2D(filters=4, kernel_size=(4,4), strides=1, padding='same', activation='sigmoid')(x)
  print(x.shape)
  return tf.keras.Model(inputs=inputs, outputs=x, name='decoder')

# %%
#@title U-Net Generator
z_dim = 200
encoder = Encoder(z_dim)
encoder2 = Encoder(z_dim)
decoder = Decoder(z_dim)

combine = layers.Concatenate()([encoder.output, encoder2.output])
combine = layers.Dense(2*z_dim, activation = 'relu')(combine)
combine = decoder(combine)
autoencoder = tf.keras.Model(inputs = [encoder.input,encoder2.input], outputs = combine)
tf.keras.utils.plot_model(autoencoder)
# Out:
# (None, 48, 48, 8)
# (None, 24, 24, 12)
# (None, 12, 12, 12)
# (None, 12, 12, 16)
# (None, 2304)
# (None, 200)
# (None, 48, 48, 8)
# (None, 24, 24, 12)
# (None, 12, 12, 12)
# (None, 12, 12, 16)
# (None, 2304)
# (None, 200)
# (None, 24, 24, 128)
# (None, 48, 48, 128)
# (None, 48, 48, 64)
# (None, 96, 96, 64)
# (None, 96, 96, 32)
# (None, 96, 96, 4)

# %%
#@title U-Net Descriminator
'''
inputs = layers.Input(shape = (Max_length, Max_length, 4))
x = layers.Conv2D(filters=64, kernel_size= 5, strides=2, padding='same', activation='relu')(inputs)
print(x.shape)
x = layers.Conv2D(filters=64, kernel_size= 5, strides=2, padding='same', activation='relu')(x)
print(x.shape)
x = layers.Flatten()(x)
x = Layers.Dense(1)(x)

Descriminator = tf.keras.Model(inputs = [encoder.input, encoder2.input], outputs = x)
'''
# Out:
# "\ninputs = layers.Input(shape = (Max_length, Max_length, 4))\nx = layers.Conv2D(filters=64, kernel_size= 5, strides=2, padding='same', activation='relu')(inputs)\nprint(x.shape)\nx = layers.Conv2D(filters=64, kernel_size= 5, strides=2, padding='same', activation='relu')(x)\nprint(x.shape)\nx = layers.Flatten()(x)\nx = Layers.Dense(1)(x)\n\nDescriminator = tf.keras.Model(inputs = [encoder.input, encoder2.input], outputs = x)\n"

# %%
model = autoencoder
model.compile(loss = "mean_squared_error", optimizer = 'adam'  )
history = model.fit((dataset_x1,dataset_x3),dataset_x2, epochs = 35,verbose = 1)
plt.plot(history.history['loss'])
plt.show()
# Out:
# Epoch 1/35
# 159/159 [==============================] - 24s 78ms/step - loss: 0.0417
# Epoch 2/35
# 159/159 [==============================] - 11s 71ms/step - loss: 0.0195
# Epoch 3/35
# 159/159 [==============================] - 11s 71ms/step - loss: 0.0170
# Epoch 4/35
# 159/159 [==============================] - 11s 71ms/step - loss: 0.0154
# Epoch 5/35
# 159/159 [==============================] - 11s 70ms/step - loss: 0.0152
# Epoch 6/35
# 159/159 [==============================] - 11s 70ms/step - loss: 0.0136
# Epoch 7/35
# 159/159 [==============================] - 12s 73ms/step - loss: 0.0128
# Epoch 8/35
# 159/159 [==============================] - 12s 73ms/step - loss: 0.0122
# Epoch 9/35
# 159/159 [==============================] - 12s 72ms/step - loss: 0.0115
# Epoch 10/35
# 159/159 [==============================] - 11s 72ms/step - loss: 0.0110
# Epoch 11/35
# 159/159 [==============================] - 11s 72ms/step - loss: 0.0107
# Epoch 12/35
# 159/159 [==============================] - 11s 71ms/step - loss: 0.0099
# Epoch 13/35
# 159/159 [==============================] - 11s 72ms/step - loss: 0.0096
# Epoch 14/35
# 159/159 [==============================] - 11s 71ms/step - loss: 0.0091
# Epoch 15/35
# 159/159 [==============================] - 11s 71ms/step - loss: 0.0087
# Epoch 16/35
# 159/159 [==============================] - 11s 71ms/step - loss: 0.0084
# Epoch 17/35
# 159/159 [==============================] - 11s 71ms/step - loss: 0.0080
# Epoch 18/35
# 159/159 [==============================] - 11s 71ms/step - loss: 0.0077
# Epoch 19/35
# 159/159 [==============================] - 11s 71ms/step - loss: 0.0072
# Epoch 20/35
# 159/159 [==============================] - 11s 71ms/step - loss: 0.0070
# Epoch 21/35
# 159/159 [==============================] - 11s 71ms/step - loss: 0.0068
# Epoch 22/35
# 159/159 [==============================] - 11s 72ms/step - loss: 0.0064
# Epoch 23/35
# 159/159 [==============================] - 11s 71ms/step - loss: 0.0062
# Epoch 24/35
# 159/159 [==============================] - 11s 71ms/step - loss: 0.0059
# Epoch 25/35
# 159/159 [==============================] - 11s 71ms/step - loss: 0.0056
# Epoch 26/35
# 159/159 [==============================] - 11s 72ms/step - loss: 0.0056
# Epoch 27/35
# 159/159 [==============================] - 11s 72ms/step - loss: 0.0053
# Epoch 28/35
# 159/159 [==============================] - 11s 72ms/step - loss: 0.0050
# Epoch 29/35
# 159/159 [==============================] - 12s 73ms/step - loss: 0.0048
# Epoch 30/35
# 159/159 [==============================] - 11s 72ms/step - loss: 0.0046
# Epoch 31/35
# 159/159 [==============================] - 11s 72ms/step - loss: 0.0045
# Epoch 32/35
# 159/159 [==============================] - 11s 72ms/step - loss: 0.0043
# Epoch 33/35
# 159/159 [==============================] - 11s 71ms/step - loss: 0.0042
# Epoch 34/35
# 159/159 [==============================] - 11s 72ms/step - loss: 0.0042
# Epoch 35/35
# 159/159 [==============================] - 11s 72ms/step - loss: 0.0041

# %% [markdown]
# #**🖌Model Post Prosceccing and Examination🖌**

# %%
#@title Color Pre/Post Proscescing Functions
def calculateDistanceBetweenColors(a, b):
  r = abs(a[0] - b[0])
  g = abs(a[1] - b[1])
  bl = abs(a[2] - b[2])
  d = abs(a[3] - b[3])
  dis = (r+g+bl+d+d)/5
  return dis

def findClosestVal(histogram, val, lean, blank_color,blank_lean,border_color,border_lean):
  high = 1
  color = [0,0,0,0]
  if blank_color != None:
    if calculateDistanceBetweenColors(val, blank_color) < blank_lean:
      return blank_color
  if border_color != None:
    if calculateDistanceBetweenColors(val, border_color) < border_lean:
      return border_color
    return color

  for cnt in range(len(histogram)):
    i = histogram[cnt]
    if calculateDistanceBetweenColors(val, i) < high:
      high = calculateDistanceBetweenColors(val, i )
      color = i
  if high > lean:
    return val
  return color

def colorSearch(histogram, val, lean):
  high = 1
  for cnt in range(len(histogram)):
    i = histogram[cnt]
    if calculateDistanceBetweenColors(val, i) < high:
      high = calculateDistanceBetweenColors(val, i )
  if high > lean:
    return False
  return True
def colorHistogramEncoder(img1, img2):

  ColorHistogram = []
  for i in range(img1.shape[0]):
    for j in range(img1.shape[1]):
      if not colorSearch(ColorHistogram, img1[i][j],.01):
        print("new")
        ColorHistogram.append(img1[i][j])
    for i in range(img2.shape[0]):
      for j in range(img2.shape[1]):
        if not colorSearch(ColorHistogram, img2[i][j],.01):
          print("new")
          ColorHistogram.append(img2[i][j])
  return ColorHistogram


def colorHistogramDecoder(img, histogram, lean, blank_color,blank_lean,border_color,border_lean):
  for i in range(img.shape[0]):
    for j in range(img.shape[1]):
      img[i][j] = findClosestVal(histogram,img[i][j],lean, blank_color,blank_lean,border_color,border_lean)
  return img

# %%
selec = 999
imgplot = plt.imshow(dataset_x1[selec])
plt.show()
imgplot = plt.imshow(dataset_x2[selec])
plt.show()
imgplot = plt.imshow(dataset_x3[selec])
plt.show()
i = model.predict([dataset_x1[selec][np.newaxis],dataset_x3[selec][np.newaxis]])
i = i[0]
imgplot = plt.imshow(i)
plt.show()

histogram = colorHistogramEncoder(dataset_x1[selec],dataset_x3[selec])
print(histogram)
border_color=[0,0,0,1]
blank_color=[0,0,0,0]

# %%
i = colorHistogramDecoder(i, histogram, .3 ,None,.5,None,.5)
imgplot = plt.imshow(i)
plt.show()
i = colorHistogramDecoder(i, histogram, .2 ,None,.5,None,.5)
imgplot = plt.imshow(i)
plt.show()
i = colorHistogramDecoder(i, histogram, .1 ,None,.5,None,.5)
imgplot = plt.imshow(i)
plt.show()






'''
for p in range(9):
  imgplot = plt.imshow(test_y[p])
  plt.show()
  i = model.predict([text_x1[p][np.newaxis],test_x2[p][np.newaxis]])
  i=i[0]
  imgplot = plt.imshow(i)
  plt.show()

'''
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-9568e745a587> in <cell line: 1>()
# ----> 1 i = colorHistogramDecoder(i, histogram, .3 ,None,.5,None,.5)
#       2 imgplot = plt.imshow(i)
#       3 plt.show()
#       4 i = colorHistogramDecoder(i, histogram, .2 ,None,.5,None,.5)
#       5 imgplot = plt.imshow(i)
#
# NameError: name 'i' is not defined

# %% [markdown]
# #**⬇Model Deployment⬇**

# %%
#@title Preview Bare Model
imgplot = plt.imshow(dataset_x1[selec])
plt.show()
imgplot = plt.imshow(dataset_x2[selec])
plt.show()
imgplot = plt.imshow(dataset_x3[selec])
plt.show()
i = model.predict([dataset_x1[selec][np.newaxis],dataset_x3[selec][np.newaxis]])
i = i[0]
imgplot = plt.imshow(i)
plt.show()
# Out:
# 1/1 [==============================] - 1s 780ms/step

# %%
#@title download Keras Model

model.save('keras_model.keras')

#from google.colab import files
#files.download('keras_model.keras')

from google.colab import drive
drive.mount('/content/drive')

model.save('/content/drive/MyDrive/ModelFolder/interpolationModel', save_format="h5")

#import shutil
#shutil.copy('source','destination')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
#@title upload Keras Model
from google.colab import drive
drive.mount('/content/drive')

model = tf.keras.models.load_model('/content/drive/MyDrive/ModelFolder/interpolationModel')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#@title Save and Download Model in ONNX Format
from google.colab import files

input_signature = [tf.TensorSpec([None, 96, 96, 4], tf.float32, name='input_1'),
                   tf.TensorSpec([None, 96, 96, 4], tf.float32, name='input_2')]

onnx_model, _ = tf2onnx.convert.from_keras(model, input_signature, opset=13)
onnx.save(onnx_model, "/content/model.onnx")
files.download("/content/model.onnx")

# %%
#@title Save and Download Model in CoreML Format

import coremltools

model.save('InterpModel1.h5')

CoreMLmodel = coremltools.convert(model, convert_to="mlprogram")
CoreMLmodel.save('InterpModel1.h5')
from google.colab import files
files.download('InterpModel1.h5')

# %%
#@title Save Model in JSON and HDF5
# Save ful model in HDF5

model.save('full_model.h5')

# Save the config in JSON Format

model_json = model.to_json()
with open("model_config.json", "w") as f:
    f.write(model_json)

# Save Weights

model.save_weights('model_weights.h5')

# Download Everything

from google.colab import files
files.download("/content/model_config.json")
files.download("/content/model_weights.h5")
files.download("/content/full_model.h5")

# %%
#@title Save Model in TFLITE
model_dir = 'saved_model/1'
tf.saved_model.save(model,model_dir,)
'''
//!zip -r /content/savedModel.zip /content/saved_model
'''
converter = tf.lite.TFLiteConverter.from_saved_model(model_dir)
tflite_model = converter.convert()
with open('model.tflite', 'wb') as f:
  f.write(tflite_model)
##from google.colab import files
#files.download("/content/model.tflite")
